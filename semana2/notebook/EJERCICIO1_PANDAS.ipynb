# %%
import pandas as pd

# %%
df_ventas = pd.read_csv('ventas.csv')
df_ventas.head()
# Out:
#    id_venta                       fecha producto    categoria  cantidad  \
# 0         1  2024-04-12T00:00:00.000000  Monitor  Electrónica         4
# 1         2  2024-06-28T00:00:00.000000  Mochila  Informática         7
# 2         3  2024-04-02T00:00:00.000000  Monitor  Electrónica         3
# 3         4  2024-01-15T00:00:00.000000  Mochila  Electrónica         6
# 4         5  2024-04-16T00:00:00.000000  Monitor  Informática         2
#
#    precio_unitario  id_cliente    total
# 0           187.05          17   748.20
# 1           317.99           1  2225.93
# 2           318.60          16   955.80
# 3           270.21          12  1621.26
# 4            49.69          19    99.38

# %%
df_clientes = pd.read_json('clientes.json')
print(df_clientes.shape[0])
# Out:
# 20

# %%
df_inventario = pd.read_excel('inventario.xlsx')
df_inventario.head()
# Out:
#    id_producto     producto    categoria  stock_disponible  precio_reposicion  \
# 0            1  Auriculares   Accesorios               116              65.98
# 1            2        Mouse   Accesorios               128              50.71
# 2            3      Teclado  Electrónica                15             138.73
# 3            4      Monitor  Informática                68              39.44
# 4            5       Webcam   Accesorios                21              40.38
#
#     proveedor
# 0  ProveedorB
# 1  ProveedorB
# 2  ProveedorA
# 3  ProveedorC
# 4  ProveedorA

# %%
promedio_stock = df_inventario['stock_disponible'].mean()
print(promedio_stock)
# Out:
# 82.25
